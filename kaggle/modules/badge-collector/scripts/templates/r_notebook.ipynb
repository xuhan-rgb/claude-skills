# %% [markdown]
# # Badge Collector — R Notebook
#
# Auto-generated R notebook for Kaggle badge collection.

# %%
# Load built-in dataset
data(iris)

# Summary statistics
summary(iris)

# Dimensions
cat("Rows:", nrow(iris), "\n")
cat("Cols:", ncol(iris), "\n")

# %%
# Group means
aggregate(. ~ Species, data = iris, FUN = mean)
